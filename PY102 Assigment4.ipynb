# %%
# Rock Paper Scissors Game
# user inputs their choice and the computer randomly selects its choice.
import random

def get_computer_choice():
    choices = ['rock', 'paper', 'scissors']
    return random.choice(choices)  
def determine_winner(user_choice, computer_choice):
    if user_choice == computer_choice:
        return 'tie'
    elif (user_choice == 'rock' and computer_choice == 'scissors') or \
         (user_choice == 'paper' and computer_choice == 'rock') or \
         (user_choice == 'scissors' and computer_choice == 'paper'):       
        return 'user'
    else:
        return 'computer'   
def play_game():
    user_score = 0
    computer_score = 0
    rounds_played = 0
    while True:
        user_choice = input("Enter rock, paper, scissors or quit to exit: ").lower()
        if user_choice == 'quit':
            break
        if user_choice not in ['rock', 'paper', 'scissors']:
            print("Invalid input. Please try again.")
            continue
        computer_choice = get_computer_choice()
        print(f"Computer chose: {computer_choice}")
        winner = determine_winner(user_choice, computer_choice)
        if winner == 'user':
            user_score += 1
            rounds_played += 1
            print("You win this round!")
        elif winner == 'computer':
            computer_score += 1
            rounds_played += 1
            print("Computer wins this round!")
        else:
            print("This round is a tie!")
        print(f"Score - You: {user_score}, Computer: {computer_score}")
        if user_score == 3:
            print("Congratulations! You won the best 3 out of 5 rounds!")
            break
        if rounds_played == 5:
            print("Best 3 out of 5 rounds completed.")
            break
    print(f"Final Score - You: {user_score}, Computer: {computer_score}")  
    user_choice = input("Play again? ").lower()
        
    
if __name__ == "__main__":
    play_game() 


# The winner is determined based on the classic rules of the game.
# The game continues until the user decides to quit.


# The program keeps track of the score.
# The user can input 'rock', 'paper', 'scissors', or 'quit' to exit the game.
# The program handles invalid inputs gracefully.
# The final score is displayed when the user quits.
# Best 3 out of 5 rounds after user wins 3 times in a row.
# Out:
# Computer chose: paper
# Computer wins this round!
# Score - You: 0, Computer: 1
# Computer chose: scissors
# Computer wins this round!
# Score - You: 0, Computer: 2
# Computer chose: rock
# Computer wins this round!
# Score - You: 0, Computer: 3
# Computer chose: paper
# Computer wins this round!
# Score - You: 0, Computer: 4
# Computer chose: rock
# You win this round!
# Score - You: 1, Computer: 4
# Best 3 out of 5 rounds completed.
# Final Score - You: 1, Computer: 4
